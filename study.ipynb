# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
happiness=pd.read_csv('world-happiness-report-2021.csv')
vac=pd.read_csv('country_vaccinations.csv')

# %%
print(happiness.head())

print(happiness.isnull().values.any())
# Out:
#   Country name Regional indicator  Ladder score
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# False

# %%
#happiness.info()
#vac.info()
mbs = happiness['Country name']
print(mbs)
# Out:
# 0        Finland
# 1        Denmark
# 2    Switzerland
# 3        Iceland
# Name: Country name, dtype: object

# %%
sns.barplot(happiness['Social support'], happiness['Healthy life expectancy'])
sns.barplot(vac['country'], vac['people_vaccinated'])
# Out:
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='country', ylabel='people_vaccinated'>

# %%
sns.displot(happiness['Social support'])
sns.displot(vac['people_vaccinated'])

# %%
sns.jointplot(happiness['Social support'], happiness['Healthy life expectancy'])
sns.jointplot(vac['country'], vac['people_vaccinated'])
# Out:
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#sns.stripplot((happiness['Freedom to make life choices'], happiness['Healthy life expectancy']))
sns.stripplot(vac['country'], vac['people_vaccinated'])
# Out:
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='country', ylabel='people_vaccinated'>

# %%
sns.boxplot(vac['country'], vac['people_vaccinated'], hue=vac['source_name'])
# Out:
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='country', ylabel='people_vaccinated'>

# %%
sns.barplot(vac['country'], vac['people_vaccinated'], hue=vac['source_name'])
# Out:
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='country', ylabel='people_vaccinated'>

# %%
sns.countplot(vac['country'])
# Out:
# c:\users\wunan\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='country', ylabel='count'>
