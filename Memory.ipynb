# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
memory=pd.read_csv('memory.csv')

# %%
print(memory.head())
print(memory.isnull().values.any())
# Out:
#           System  Copy MB/s  Scale MB/s  Triad MB/s  Add MB/s
# 0     Bare Metal      25281       17553       19153     19147
# 1     Hyper-V VM      28668       18375       21516     21187
# 2  VirtualBox VM      39107       28388       31648     31587
# False

# %%
system = memory['System']
copy = memory['Copy MB/s']
scale = memory['Scale MB/s']

triad = memory['Triad MB/s']
add = memory['Add MB/s']


# print(copy)
# print(scale)

# print(triad)
# print(add)

fig, axes = plt.subplots(1, 4, figsize=(18, 10))
fig.suptitle('Memery Performance')

sns.boxplot(ax=axes[0], x=system, y=copy)
sns.boxplot(ax=axes[1], x=system, y=scale)
sns.boxplot(ax=axes[2], x=system, y=triad)
sns.boxplot(ax=axes[3], x=system, y=add)
# Out:
# <AxesSubplot:xlabel='System', ylabel='Add MB/s'>

# %%
system = fio['System']
copy = memory['Copy MB/s']
scale = memory['Scale MB/s']

triad = memory['Triad MB/s']
add = memory['Add MB/s']


# print(copy)
# print(scale)

# print(triad)
# print(add)

fig, axes = plt.subplots(1, 4, figsize=(15, 5))
fig.suptitle('Memery Performance')

sns.barplot(ax=axes[0], x=system, y=copy)
sns.barplot(ax=axes[1], x=system, y=scale)
sns.barplot(ax=axes[2], x=system, y=triad)
sns.barplot(ax=axes[3], x=system, y=add)
# Out:
# <AxesSubplot:xlabel='System', ylabel='Add MB/s'>
